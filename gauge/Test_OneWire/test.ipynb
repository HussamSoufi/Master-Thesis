# %%
import pandas as pd
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
#headers = ['ID', 'Date','pH', 'ORP', 'Temp', 'DO', 'EC', 'NaN']
df = pd.read_csv('C:/Users/hussa/Desktop/gauge/cpu.csv')
print (df)

df['Date'] = df['Date'].map(lambda x: datetime.strptime(str(x), '%Y-%m-%d %H:%M:%S'))


x = df['Date']
y = df['pH']


# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()
# Out:
#                   Date     pH    ORP    Temp     DO    EC  NaN
# 0  2019-08-04 10:51:42  3.815  239.6  23.344  10.93  0.00  NaN
# 1  2019-09-22 15:49:17  3.854  398.6  20.430  11.02  9.22  NaN
# 2  2019-09-22 15:49:47  3.854  398.6  20.430  11.02  9.22  NaN
# 3  2019-09-25 17:45:49  3.832  482.5  20.931  10.78  9.48  NaN
# 4  2019-09-26 17:45:49  3.832  482.5  20.931  10.78  9.48  NaN
# 5  2019-09-27 17:45:49  3.832  482.5  20.931  10.78  9.48  NaN
# 6  2019-09-28 17:45:49  3.832  482.5  20.931  10.78  9.48  NaN
# 7  2019-10-20 17:45:49  3.832  482.5  20.931  10.78  9.48  NaN
